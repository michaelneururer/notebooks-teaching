# %% [markdown]
# # This sage worksheet is part of the exercise class for the course
# # <p style="text-align: center;"> L-functions and applications </p>
# # that I taught jointly with Jolanta Marzec in the s.

# %% [markdown]
# ## Exercise 1)
# Write a function that returns a list of all prime numbers below x.
#
# <font color ="green"> Allowed functions: Only basic Python functions and sqrt </font>

# %%
#Fill in the code below
def prime_list(n):
    if n<=2:
        return [] #That's the empty list
    if n==2:
        return [2]
    L = []
    for i in range(2,n):
        L.append(i)
    return L

# %% [markdown]
# ### <font color ="teal"> Compare your function to the sage inbuilt function primes(n) </font>
# From now on we will use the sage inbuilt function

# %%
timeit('primes(100000)', preparse=None, number=1, repeat=1, precision=3)
# Out:
# 1 loops, best of 1: 5.01 µs per loop

# %%
# %timeit prime_list(1000)

# %% [markdown]
# ## Exercise 2)
# Plot the function $\pi(x)=\#\left\{p\in\mathbb{P}|\,p < x\right\}$ for $x<10000000$ and compare it to $\frac{x}{\log(x)}$
#
# <font color ="green"> Allowed functions: primes, plot </font>

# %%
prime_list = list(primes(10000000))

# %%
plot(sin(x),0,10) + plot(cos(x), 0,10,color='red')

# %% [markdown]
# ## Exercise 3)
# Let $a$ and $m$ be coprime. Write a function that computes $$\pi_{a,m}(x)=\#\{p\in\mathbb{P}|\,p < x, p\equiv a\mod m\}$$
# Check the growth of $\pi_{a,m}(x)$ as $a$ and $m$ vary. Make a conjecture about the asymptotic growth of $\pi_{a,m}$.
#
# <font color ="green"> Allowed functions: primes, plot </font>

# %% [markdown]
# ## Exercise 4)
#
# Check that $\pi_{3,4}(x)$ is usually bigger than $\pi_{1,4}(x)$ and find the first $x\in\mathbb{N}$ such that $\pi_{1,4}(x)>\pi_{3,4}(x)$
