# %% [markdown]
# # This sage worksheet accompanies my paper  (joint with Abhishek Saha and Kęstutis Česnavičius)
# # <p style="text-align: center;"> ['The Manin constant and the modular degree'](https://arxiv.org/abs/1911.09446) </p>

# %% [markdown]
# # Denominators of Fourier expansions
# We calculate, for various levels $N$ and weights $k$, the denominators of Fourier expansions of all newforms at some cusps of $X_0(N)$. The difference to the worksheet examples_for_global_bounds is that here we also check weights greater than $2$.
#
# ### <font color ="green"> Requirements: SageMath and the function get_expansions from the python package [products-of-eisenstein-series](https://github.com/michaelneururer/products-of-eisenstein-series) (joint work with Martin Dickson) to calculate the Fourier expansions. </font>

# %%
p=2; N=p^2;
print 'LEVEL', N
minima = {}
for k in range(2,14,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 4
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 0
# WEIGHT 6
# Number of ratioal newforms 1
# Newform number 0
# q - 12*q^3 + 54*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 2, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# WEIGHT 8
# Number of ratioal newforms 0
# WEIGHT 10
# Number of ratioal newforms 1
# Newform number 0
# q + 228*q^3 - 666*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 2, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# WEIGHT 12
# Number of ratioal newforms 1
# Newform number 0
# q - 516*q^3 - 10530*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 2, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# ALL MINIMA {2: [], 4: [], 6: [0], 8: [], 10: [0], 12: [0]}

# %%
p=2; N=3*p^2;
print 'LEVEL', N
minima = {}
for k in range(2,14,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 12
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 3*q^3 - 18*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# WEIGHT 6
# Number of ratioal newforms 0
# WEIGHT 8
# Number of ratioal newforms 2
# Newform number 0
# q - 27*q^3 - 378*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 6, +Infinity, 0]
# Minimum
# 0
# Newform number 1
# q + 27*q^3 + 270*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# WEIGHT 10
# Number of ratioal newforms 1
# Newform number 0
# q - 81*q^3 + 990*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 7, +Infinity, 0]
# Minimum
# 0
# WEIGHT 12
# Number of ratioal newforms 2
# Newform number 0
# q - 243*q^3 + 9990*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 4, +Infinity, 0]
# Minimum
# 0
# Newform number 1
# q + 243*q^3 + 2862*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, 3, +Infinity, 0]
# Minimum
# 0
# ALL MINIMA {2: [], 4: [0], 6: [], 8: [0, 0], 10: [0], 12: [0, 0]}

# %%
p=2; N=9*p^2;
print 'LEVEL', N
minima = {}
for k in range(2,8,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 36
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 2, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 18*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, 1, +Infinity, 3, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 6
# Number of ratioal newforms 2
# Newform number 0
# q - 54*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, 1, +Infinity, 3, +Infinity, +Infinity]
# Minimum
# 0
# Newform number 1
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 2, +Infinity, +Infinity]
# Minimum
# 0
# ALL MINIMA {2: [0], 4: [0], 6: [0, 0]}

# %%
p=3; N=p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,14,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q - 8*q^4 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 6
# Number of ratioal newforms 1
# Newform number 0
# q + 6*q^2 + 4*q^4 - 6*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 1/2, 3/2, -1/2, 1/2, 5/2, -1/2, 1/2, 7/2]
# Minimum
# -1/2
# WEIGHT 8
# Number of ratioal newforms 1
# Newform number 0
# q - 6*q^2 - 92*q^4 - 390*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 1/2, 5/2, -1/2, 1/2, 7/2, -1/2, 1/2, 11/2]
# Minimum
# -1/2
# WEIGHT 10
# Number of ratioal newforms 3
# Newform number 0
# q - 18*q^2 - 188*q^4 + 1530*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 3/2, 7/2, -1/2, 3/2, 11/2, -1/2, 3/2, 15/2]
# Minimum
# -1/2
# Newform number 1
# q - 512*q^4 + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# Newform number 2
# q + 36*q^2 + 784*q^4 + 1314*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 3/2, 7/2, -1/2, 3/2, 11/2, -1/2, 3/2, 15/2]
# Minimum
# -1/2
# WEIGHT 12
# Number of ratioal newforms 2
# Newform number 0
# q - 78*q^2 + 4036*q^4 + 5370*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 1/2, 9/2, -1/2, 1/2, 11/2, -1/2, 1/2, 19/2]
# Minimum
# -1/2
# Newform number 1
# q + 24*q^2 - 1472*q^4 - 4830*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, 1/2, 3/2, -1/2, 1/2, 5/2, -1/2, 1/2, 7/2]
# Minimum
# -1/2
# ALL MINIMA {2: [], 4: [0], 6: [-1/2], 8: [-1/2], 10: [-1/2, 0, -1/2], 12: [-1/2, -1/2]}

# %%
p=3; N=2*p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,14,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 2*q^2 + 4*q^4 - 6*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 1/2, -1/2, 1/2, 1/2, -1/2, -1/2, 3/2]
# Minimum
# -1/2
# WEIGHT 6
# Number of ratioal newforms 3
# Newform number 0
# q - 4*q^2 + 16*q^4 - 96*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 1
# q - 4*q^2 + 16*q^4 + 66*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 3/2, -1/2, 1/2, 3/2, -1/2, -1/2, 7/2]
# Minimum
# -1/2
# Newform number 2
# q + 4*q^2 + 16*q^4 + 96*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# WEIGHT 8
# Number of ratioal newforms 2
# Newform number 0
# q - 8*q^2 + 64*q^4 + 114*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 5/2, -1/2, 1/2, 5/2, -1/2, -1/2, 11/2]
# Minimum
# -1/2
# Newform number 1
# q + 8*q^2 + 64*q^4 + 210*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 1/2, -1/2, 1/2, 1/2, -1/2, -1/2, 3/2]
# Minimum
# -1/2
# WEIGHT 10
# Number of ratioal newforms 4
# Newform number 0
# q - 16*q^2 + 256*q^4 - 870*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 1/2, -1/2, 1/2, 1/2, -1/2, -1/2, 3/2]
# Minimum
# -1/2
# Newform number 1
# q - 16*q^2 + 256*q^4 - 384*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 2
# q + 16*q^2 + 256*q^4 - 2694*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 7/2, -1/2, 1/2, 7/2, -1/2, -1/2, 15/2]
# Minimum
# -1/2
# Newform number 3
# q + 16*q^2 + 256*q^4 + 384*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# WEIGHT 12
# Number of ratioal newforms 5
# Newform number 0
# q - 32*q^2 + 1024*q^4 - 3630*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 9/2, -1/2, 1/2, 9/2, -1/2, -1/2, 19/2]
# Minimum
# -1/2
# Newform number 1
# q - 32*q^2 + 1024*q^4 + 5280*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 2
# q + 32*q^2 + 1024*q^4 - 5766*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 9/2, -1/2, 1/2, 9/2, -1/2, -1/2, 19/2]
# Minimum
# -1/2
# Newform number 3
# q + 32*q^2 + 1024*q^4 - 5280*q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 4
# q + 32*q^2 + 1024*q^4 + 11730*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, 9/2, -1/2, 1/2, 9/2, -1/2, -1/2, 19/2]
# Minimum
# -1/2
# ALL MINIMA {2: [], 4: [-1/2], 6: [0, -1/2, 0], 8: [-1/2, -1/2], 10: [-1/2, 0, -1/2, 0], 12: [-1/2, 0, -1/2, 0, -1/2]}

# %%
p=3; N=2*5*p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 90
# WEIGHT 2
# Number of ratioal newforms 3
# Newform number 0
# q - q^2 + q^4 + q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 0, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 1
# q + q^2 + q^4 - q^5 + O(q^6)
# Denominators
# [+Infinity, 0, 0, +Infinity, 0, 0, +Infinity, 0, 0, +Infinity]
# Minimum
# 0
# Newform number 2
# q + q^2 + q^4 + q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2]
# Minimum
# -1/2
# ALL MINIMA {2: [0, 0, -1/2]}

# %%
p=3; N=4*p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,12,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 18*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# WEIGHT 6
# Number of ratioal newforms 2
# Newform number 0
# q - 54*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# Newform number 1
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 8
# Number of ratioal newforms 3
# Newform number 0
# q - 270*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 5/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 11/2]
# Minimum
# -1/2
# Newform number 1
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# Newform number 2
# q + 378*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 5/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 11/2]
# Minimum
# -1/2
# WEIGHT 10
# Number of ratioal newforms 2
# Newform number 0
# q - 990*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 7/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 15/2]
# Minimum
# -1/2
# Newform number 1
# q + 666*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# ALL MINIMA {8: [-1/2, 0, -1/2], 2: [0], 4: [-1/2], 10: [-1/2, -1/2], 6: [-1/2, 0]}

# %%
p=3; N=4*p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,12,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/(2*p), prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 36
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 18*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# WEIGHT 6
# Number of ratioal newforms 2
# Newform number 0
# q - 54*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# Newform number 1
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# WEIGHT 8
# Number of ratioal newforms 3
# Newform number 0
# q - 270*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 5/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 11/2]
# Minimum
# -1/2
# Newform number 1
# q + O(q^6)
# Denominators
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity]
# Minimum
# 0
# Newform number 2
# q + 378*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 5/2, +Infinity, 5/2, +Infinity, -1/2, +Infinity, 11/2]
# Minimum
# -1/2
# WEIGHT 10
# Number of ratioal newforms 2
# Newform number 0
# q - 990*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 7/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 15/2]
# Minimum
# -1/2
# Newform number 1
# q + 666*q^5 + O(q^6)
# Denominators
# [+Infinity, -1/2, +Infinity, 1/2, +Infinity, 3/2, +Infinity, -1/2, +Infinity, 3/2]
# Minimum
# -1/2
# ALL MINIMA {8: [-1/2, 0, -1/2], 2: [0], 4: [-1/2], 10: [-1/2, -1/2], 6: [-1/2, 0]}

# %%
p=5; N=p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,10,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 3
# Newform number 0
# q - q^2 - 7*q^3 - 7*q^4 + O(q^6)
# Denominators
# [+Infinity, -1/4, -1/4, -1/4, -1/4, +Infinity, -1/4, -1/4, 3/4, -1/4]
# Minimum
# -1/4
# Newform number 1
# q + q^2 + 7*q^3 - 7*q^4 + O(q^6)
# Denominators
# [+Infinity, 0, 0, 0, 0, +Infinity, 0, 0, 1, 0]
# Minimum
# 0
# Newform number 2
# q + 4*q^2 - 2*q^3 + 8*q^4 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, 1/2, -1/2, -1/2, +Infinity, -1/2]
# Minimum
# -1/2
# WEIGHT 6
# Number of ratioal newforms 1
# Newform number 0
# q - 2*q^2 + 4*q^3 - 28*q^4 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, 3/2, -1/2, -1/2, 1/2, -1/2]
# Minimum
# -1/2
# WEIGHT 8
# Number of ratioal newforms 1
# Newform number 0
# q + 14*q^2 + 48*q^3 + 68*q^4 + O(q^6)
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, 5/2, -1/2, -1/2, 1/2, -1/2]
# Minimum
# -1/2
# ALL MINIMA {8: [-1/2], 2: [], 4: [-1/4, 0, -1/2], 6: [-1/2]}

# %%
p=5; N=3*p^2; 
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print latex(n.qexp(10))
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        print 'Expansion at cusp 1/p^2', s2
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 75
# WEIGHT 2
# Number of ratioal newforms 3
# Newform number 0
# q - 2q^{2} + q^{3} + 2q^{4} - 2q^{6} + 3q^{7} + q^{9} + O(q^{10})
# (-1/3*zeta600^100 + 1/3)*q3 - 2/3*zeta600^100*q3^2 - 1/3*q3^3 + (-2/3*zeta600^100 + 2/3)*q3^4 + 2/3*q3^6 + (-zeta600^100 + 1)*q3^7 - 1/3*q3^9 + 2/3*zeta600^100*q3^11 - 2/3*q3^12 + (1/3*zeta600^100 - 1/3)*q3^13 - 2*zeta600^100*q3^14 + (4/3*zeta600^100 - 4/3)*q3^16 - 2/3*zeta600^100*q3^17 + 2/3*q3^18 + (5/3*zeta600^100 - 5/3)*q3^19 - q3^21 + (4/3*zeta600^100 - 4/3)*q3^22 - 2*zeta600^100*q3^23 + 2/3*zeta600^100*q3^26 - 1/3*q3^27 + (-2*zeta600^100 + 2)*q3^28 + 10/3*zeta600^100*q3^29 + O(q3^30)
#
# Denominators
# [+Infinity, 0, 0, 0, 0, +Infinity, 0, 0, +Infinity, 0]
# Minimum
# 0
# Newform number 1
# q + q^{2} + q^{3} - q^{4} + q^{6} - 3q^{8} + q^{9} + O(q^{10})
# (-1/3*zeta600^100 + 1/3)*q3 + 1/3*zeta600^100*q3^2 - 1/3*q3^3 + (1/3*zeta600^100 - 1/3)*q3^4 - 1/3*q3^6 - zeta600^100*q3^8 - 1/3*q3^9 - 4/3*zeta600^100*q3^11 + 1/3*q3^12 + (-2/3*zeta600^100 + 2/3)*q3^13 + (1/3*zeta600^100 - 1/3)*q3^16 - 2/3*zeta600^100*q3^17 - 1/3*q3^18 + (-4/3*zeta600^100 + 4/3)*q3^19 + (4/3*zeta600^100 - 4/3)*q3^22 + q3^24 + 2/3*zeta600^100*q3^26 - 1/3*q3^27 - 2/3*zeta600^100*q3^29 + O(q3^30)
#
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, +Infinity, -1/2, -1/2]
# Minimum
# -1/2
# Newform number 2
# q + 2q^{2} - q^{3} + 2q^{4} - 2q^{6} - 3q^{7} + q^{9} + O(q^{10})
# (1/3*zeta600^100 - 1/3)*q3 - 2/3*zeta600^100*q3^2 - 1/3*q3^3 + (2/3*zeta600^100 - 2/3)*q3^4 - 2/3*q3^6 + (-zeta600^100 + 1)*q3^7 + 1/3*q3^9 - 2/3*zeta600^100*q3^11 - 2/3*q3^12 + (1/3*zeta600^100 - 1/3)*q3^13 + 2*zeta600^100*q3^14 + (-4/3*zeta600^100 + 4/3)*q3^16 - 2/3*zeta600^100*q3^17 + 2/3*q3^18 + (-5/3*zeta600^100 + 5/3)*q3^19 + q3^21 + (4/3*zeta600^100 - 4/3)*q3^22 - 2*zeta600^100*q3^23 - 2/3*zeta600^100*q3^26 - 1/3*q3^27 + (-2*zeta600^100 + 2)*q3^28 - 10/3*zeta600^100*q3^29 + O(q3^30)
#
# Denominators
# [+Infinity, -1/4, -1/4, -1/4, -1/4, +Infinity, -1/4, -1/4, +Infinity, -1/4]
# Minimum
# -1/4
# ALL MINIMA {2: [0, -1/2, -1/4]}

# %%
p=7; N=p^2;
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        print 'Expansion at cusp 1/p^2', s2
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 49
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q + q^2 - q^4 + O(q^6)
# q1 + q1^2 - q1^4 - 3*q1^8 - 3*q1^9 + O(q1^10)
#
# Denominators
# [+Infinity, -1/6, -1/6, +Infinity, -1/6, +Infinity, +Infinity, +Infinity, -1/6, -1/6]
# Minimum
# -1/6
# ALL MINIMA {2: [-1/6]}

# %%
p=7; N=2*p^2;
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        print 'Expansion at cusp 1/p^2', s2
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 98
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q - q^2 + 2*q^3 + q^4 + O(q^6)
# -1/2*q2 - 1/2*q2^2 - q2^3 + 1/2*q2^4 - q2^6 - 1/2*q2^8 - 1/2*q2^9 + q2^12 - 2*q2^13 + 1/2*q2^16 + 3*q2^17 - 1/2*q2^18 + q2^19 + O(q2^20)
#
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, +Infinity, -1/2, -1/2, -1/2, -1/2]
# Minimum
# -1/2
# ALL MINIMA {2: [-1/2]}

# %%
p=7; N=3*p^2;
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 147
# WEIGHT 2
# Number of ratioal newforms 3
# Newform number 0
# q - q^2 - q^3 - q^4 + 2*q^5 + O(q^6)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-77db24a16ed5> in <module>()
#      13         print 'Newform number', j
#      14         print n
# ---> 15         s = get_expansion(n, mat = Integer(1)/p, prec=Integer(10),verbose=False); #Calculate Fourier expansion of the newform
#      16         K = s.series.base_ring() #Number field
#      17         P = K.prime_above(p)
#
# /home/neururer/products-of-eisenstein-series/get_expansions.py in get_expansion(f, prec, mat, group, base_ring, verbose, eis_alt)
#     145     if verbose:
#     146         print('Finding coefficients of linear combination...')
# --> 147     sol, ind = lin_comb(f, verbose=verbose)
#     148     if verbose:
#     149         print('{} coefficients are non-zero'.
#
# /home/neururer/products-of-eisenstein-series/get_expansions.py in lin_comb(f, weights, base_ring, hom, verbose)
#      49                                         k,
#      50                                         weights=weights,
# ---> 51                                         base_ring=base_ring, verbose=verbose)
#      52     if verbose:
#      53         print('Done: There are {} products with {} coefficients each.'.
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6010)()
#    1001                 return self.cache[k]
#    1002         except KeyError:
# -> 1003             w = self.f(*args, **kwds)
#    1004             self.cache[k] = w
#    1005             return w
#
# /home/neururer/products-of-eisenstein-series/products.pyc in product_space(chi, k, weights, base_ring, verbose)
#     171                             E = (E1 * E2 + O(q**sturm)).padded_list()
#     172                             try:
# --> 173                                 products.T.solve_right(vector(base_ring,E))
#     174                             except ValueError:
#     175                                 products = Matrix(products.rows()+[E])
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.solve_right (build/cythonized/sage/matrix/matrix2.c:7824)()
#     457
#     458         if not self.is_square():
# --> 459             X = self._solve_right_general(C, check=check)
#     460             if not matrix:
#     461                 # Convert back to a vector
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix._solve_right_general (build/cythonized/sage/matrix/matrix2.c:8747)()
#     566         pivot_cols = self.pivots()
#     567         A = self.matrix_from_columns(pivot_cols)
# --> 568         pivot_rows = A.pivot_rows()
#     569         A = A.matrix_from_rows(pivot_rows)
#     570         X = A.solve_right(B.matrix_from_rows(pivot_rows), check=False)
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.pivot_rows (build/cythonized/sage/matrix/matrix2.c:8523)()
#     534         if v is not None:
#     535             return tuple(v)
# --> 536         v = self.transpose().pivots()
#     537         self.cache('pivot_rows', v)
#     538         return v
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix0.pyx in sage.matrix.matrix0.Matrix.pivots (build/cythonized/sage/matrix/matrix0.c:28622)()
#    4294         x = self.fetch('pivots')
#    4295         if not x is None: return tuple(x)
# -> 4296         self.echelon_form()
#    4297         x = self.fetch('pivots')
#    4298         if x is None:
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix_cyclo_dense.pyx in sage.matrix.matrix_cyclo_dense.Matrix_cyclo_dense.echelon_form (build/cythonized/sage/matrix/matrix_cyclo_dense.cpp:15540)()
#    1592
#    1593         if algorithm == 'multimodular':
# -> 1594             E = self._echelon_form_multimodular(height_guess=height_guess)
#    1595         elif algorithm == 'classical':
#    1596             E = (self*self.denominator())._echelon_classical()
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix_cyclo_dense.pyx in sage.matrix.matrix_cyclo_dense.Matrix_cyclo_dense._echelon_form_multimodular (build/cythonized/sage/matrix/matrix_cyclo_dense.cpp:16225)()
#    1676                 if (n == 1) or p % n == 1:
#    1677                     try:
# -> 1678                         mod_p_ech, piv_ls = A._echelon_form_one_prime(p)
#    1679                     except ValueError:
#    1680                         # This means that we chose a prime which divides
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix_cyclo_dense.pyx in sage.matrix.matrix_cyclo_dense.Matrix_cyclo_dense._echelon_form_one_prime (build/cythonized/sage/matrix/matrix_cyclo_dense.cpp:18092)()
#    1826
#    1827         # TODO: coercion going on here
# -> 1828         reduction = matrix(ZZ, len(ech_ls), self._nrows * self._ncols,
#    1829                            [ [y.lift() for y in E.list()] for E in ech_ls])
#    1830
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/constructor.pyx in sage.matrix.constructor.matrix (build/cythonized/sage/matrix/constructor.c:2417)()
#     623       :class:`MatrixArgs`, see :trac:`24742`
#     624     """
# --> 625     return MatrixArgs(*args, **kwds).matrix()
#     626
#     627
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/args.pyx in sage.matrix.args.MatrixArgs.matrix (build/cythonized/sage/matrix/args.c:7583)()
#     644             True
#     645         """
# --> 646         self.finalize()
#     647
#     648         cdef Matrix M
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/args.pyx in sage.matrix.args.MatrixArgs.finalize (build/cythonized/sage/matrix/args.c:10179)()
#     926
#     927         if self.space is None:
# --> 928             self.space = MatrixSpace(self.base, self.nrows, self.ncols,
#     929                     sparse=self.sparse, **self.kwds)
#     930
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/misc/classcall_metaclass.pyx in sage.misc.classcall_metaclass.ClasscallMetaclass.__call__ (build/cythonized/sage/misc/classcall_metaclass.c:1734)()
#     333         """
#     334         if cls.classcall is not None:
# --> 335             return cls.classcall(cls, *args, **kwds)
#     336         else:
#     337             # Fast version of type.__call__(cls, *args, **kwds)
#
# /opt/SageMath-8.8/local/lib/python2.7/site-packages/sage/matrix/matrix_space.pyc in __classcall__(cls, base_ring, nrows, ncols, sparse, implementation)
#     430     _no_generic_basering_coercion = True
#     431
# --> 432     @staticmethod
#     433     def __classcall__(cls, base_ring, nrows, ncols=None, sparse=False, implementation=None):
#     434         """
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
p=11; N=p^2;
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        if n.atkin_lehner_eigenvalue()==1:
            print 'Central L-value vanishes. We cant calculate the expansion at 1/p with our algorithm'
            j+=1
            continue
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        print 'Expansion at cusp 1/p^2', s2
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 121
# WEIGHT 2
# Number of ratioal newforms 4
# Newform number 0
# q - q^2 + 2*q^3 - q^4 + q^5 + O(q^6)
# Expansion at cusp 1/p^2 q1 - q1^2 + 2*q1^3 - q1^4 + q1^5 - 2*q1^6 + 2*q1^7 + 3*q1^8 + q1^9 + O(q1^10)
#
# Denominators
# [+Infinity, -1/10, -1/10, -1/10, -1/10, -1/10, -1/10, -1/10, -1/10, -1/10]
# Minimum
# -1/10
# Newform number 1
# q - q^3 - 2*q^4 - 3*q^5 + O(q^6)
# Central L-value vanishes. We cant calculate the expansion at 1/p with our algorithm
# Newform number 1
# q + q^2 + 2*q^3 - q^4 + q^5 + O(q^6)
# Expansion at cusp 1/p^2 q1 + q1^2 + 2*q1^3 - q1^4 + q1^5 + 2*q1^6 - 2*q1^7 - 3*q1^8 + q1^9 + O(q1^10)
#
# Denominators
# [+Infinity, -3/10, -3/10, -3/10, -3/10, -3/10, -3/10, -3/10, -3/10, -3/10]
# Minimum
# -3/10
# Newform number 2
# q + 2*q^2 - q^3 + 2*q^4 + q^5 + O(q^6)
# Expansion at cusp 1/p^2 q1 + 2*q1^2 - q1^3 + 2*q1^4 + q1^5 - 2*q1^6 + 2*q1^7 - 2*q1^9 + O(q1^10)
#
# Denominators
# [+Infinity, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, +Infinity, -1/2]
# Minimum
# -1/2
# ALL MINIMA {2: [-1/10, -3/10, -1/2]}

# %%
n.atkin_lehner_eigenvalue()
# Out:
# 1

# %%
p=2; N=p^3;
print 'LEVEL', N
minima = {}
for k in range(2,14,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 8
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q - 4*q^3 - 2*q^5 + O(q^6)
# Denominators
# [+Infinity, -2, +Infinity, 0, +Infinity, -1, +Infinity, 1, +Infinity, -2]
# Minimum
# -2
# WEIGHT 6
# Number of ratioal newforms 1
# Newform number 0
# q + 20*q^3 - 74*q^5 + O(q^6)
# Denominators
# [+Infinity, -3, +Infinity, -1, +Infinity, -2, +Infinity, 0, +Infinity, -3]
# Minimum
# -3
# WEIGHT 8
# Number of ratioal newforms 2
# Newform number 0
# q - 84*q^3 - 82*q^5 + O(q^6)
# Denominators
# [+Infinity, -4, +Infinity, -2, +Infinity, -3, +Infinity, -1, +Infinity, -4]
# Minimum
# -4
# Newform number 1
# q + 44*q^3 + 430*q^5 + O(q^6)
# Denominators
# [+Infinity, -4, +Infinity, -2, +Infinity, -3, +Infinity, -1, +Infinity, -4]
# Minimum
# -4
# WEIGHT 10
# Number of ratioal newforms 2
# Newform number 0
# q - 60*q^3 - 2074*q^5 + O(q^6)
# Denominators
# [+Infinity, -5, +Infinity, -3, +Infinity, -4, +Infinity, -2, +Infinity, -5]
# Minimum
# -5
# Newform number 1
# q + 68*q^3 + 1510*q^5 + O(q^6)
# Denominators
# [+Infinity, -5, +Infinity, -3, +Infinity, -4, +Infinity, -2, +Infinity, -5]
# Minimum
# -5
# WEIGHT 12
# Number of ratioal newforms 1
# Newform number 0
# q - 36*q^3 - 3490*q^5 + O(q^6)
# Denominators
# [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# Minimum
# -6
# ALL MINIMA {2: [], 4: [-2], 6: [-3], 8: [-4, -4], 10: [-5, -5], 12: [-6]}

# %%
p=2; N=p^4;
print 'LEVEL', N
minima = {}
minima2 = {}
for k in range(2,14,2):
    minima[k] = []
    minima2[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        K2 = s2.series.base_ring()
        P = K.prime_above(p)
        P2 = K2.prime_above(p)
        print('Denominators')
        print 'cusp 1/2', [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'cusp 1/4', [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
        print 'Minimum'
        print 'cusp 1/2', min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        print 'cusp 1/4', min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        minima2[k].append(min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA, cusp 1/2', minima
print 'All MINIMA, cusp 1/4', minima2
# Out:
#  LEVEL 16
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 1
# Newform number 0
# q + 4*q^3 - 2*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -4, +Infinity, -2, +Infinity, -3, +Infinity, -1, +Infinity, -4]
# cusp 1/4 [+Infinity, +Infinity, 2, +Infinity, +Infinity, +Infinity, 4, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -4
# cusp 1/4 2
# WEIGHT 6
# Number of ratioal newforms 2
# Newform number 0
# q - 20*q^3 - 74*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/4 [+Infinity, +Infinity, 3, +Infinity, +Infinity, +Infinity, 5, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -6
# cusp 1/4 3
# Newform number 1
# q + 12*q^3 + 54*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -6
# cusp 1/4 6
# WEIGHT 8
# Number of ratioal newforms 3
# Newform number 0
# q - 44*q^3 + 430*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/4 [+Infinity, +Infinity, 4, +Infinity, +Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 4
# Newform number 1
# q - 12*q^3 - 210*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 7, +Infinity, +Infinity, +Infinity, 10, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 7
# Newform number 2
# q + 84*q^3 - 82*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/4 [+Infinity, +Infinity, 4, +Infinity, +Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 4
# WEIGHT 10
# Number of ratioal newforms 4
# Newform number 0
# q - 228*q^3 - 666*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -10, +Infinity, -8, +Infinity, -9, +Infinity, -7, +Infinity, -10]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 10, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -10
# cusp 1/4 10
# Newform number 1
# q - 68*q^3 + 1510*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -10, +Infinity, -8, +Infinity, -9, +Infinity, -7, +Infinity, -10]
# cusp 1/4 [+Infinity, +Infinity, 5, +Infinity, +Infinity, +Infinity, 7, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -10
# cusp 1/4 5
# Newform number 2
# q + 60*q^3 - 2074*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -10, +Infinity, -8, +Infinity, -9, +Infinity, -7, +Infinity, -10]
# cusp 1/4 [+Infinity, +Infinity, 5, +Infinity, +Infinity, +Infinity, 7, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -10
# cusp 1/4 5
# Newform number 3
# q + 156*q^3 + 870*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -10, +Infinity, -8, +Infinity, -9, +Infinity, -7, +Infinity, -10]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 9, +Infinity, +Infinity, +Infinity, 13, +Infinity]
# Minimum
# cusp 1/2 -10
# cusp 1/4 9
# WEIGHT 12
# Number of ratioal newforms 3
# Newform number 0
# q - 252*q^3 + 4830*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 11, +Infinity, +Infinity, +Infinity, 14, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 11
# Newform number 1
# q + 36*q^3 - 3490*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity, 8, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 6
# Newform number 2
# q + 516*q^3 - 10530*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, +Infinity, +Infinity, +Infinity, 12, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 12
# ALL MINIMA, cusp 1/2 {2: [], 4: [-4], 6: [-6, -6], 8: [-8, -8, -8], 10: [-10, -10, -10, -10], 12: [-12, -12, -12]}
# All MINIMA, cusp 1/4 {2: [], 4: [2], 6: [3, 6], 8: [4, 7, 4], 10: [10, 5, 5, 9], 12: [11, 6, 12]}

# %%
p=2; N=p^5;
print 'LEVEL', N
minima = {}
minima2 = {}
for k in range(2,14,2):
    minima[k] = []
    minima2[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of ratioal newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        K2 = s2.series.base_ring()
        P = K.prime_above(p)
        P2 = K2.prime_above(p)
        print('Denominators')
        print 'cusp 1/2', [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'cusp 1/4', [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
        print 'Minimum'
        print 'cusp 1/2', min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        print 'cusp 1/4', min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        minima2[k].append(min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA, cusp 1/2', minima
print 'All MINIMA, cusp 1/4', minima2
# Out:
# LEVEL 32
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q - 2*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -3, +Infinity, +Infinity, +Infinity, -2, +Infinity, +Infinity, +Infinity, -3]
# cusp 1/4 [+Infinity, -1, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity, +Infinity, -1]
# Minimum
# cusp 1/2 -3
# cusp 1/4 -1
# WEIGHT 4
# Number of ratioal newforms 3
# Newform number 0
# q - 8*q^3 - 10*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -6, +Infinity, -3, +Infinity, -5, +Infinity, -2, +Infinity, -6]
# cusp 1/4 [+Infinity, -2, +Infinity, 1, +Infinity, -1, +Infinity, 2, +Infinity, -2]
# Minimum
# cusp 1/2 -6
# cusp 1/4 -2
# Newform number 1
# q + 22*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -6, +Infinity, +Infinity, +Infinity, -5, +Infinity, +Infinity, +Infinity, -6]
# cusp 1/4 [+Infinity, -2, +Infinity, +Infinity, +Infinity, -1, +Infinity, +Infinity, +Infinity, -2]
# Minimum
# cusp 1/2 -6
# cusp 1/4 -2
# Newform number 2
# q + 8*q^3 - 10*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -6, +Infinity, -3, +Infinity, -5, +Infinity, -2, +Infinity, -6]
# cusp 1/4 [+Infinity, -2, +Infinity, 1, +Infinity, -1, +Infinity, 2, +Infinity, -2]
# Minimum
# cusp 1/2 -6
# cusp 1/4 -2
# WEIGHT 6
# Number of ratioal newforms 3
# Newform number 0
# q - 8*q^3 + 14*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -9, +Infinity, -6, +Infinity, -8, +Infinity, -5, +Infinity, -9]
# cusp 1/4 [+Infinity, -3, +Infinity, 0, +Infinity, -2, +Infinity, 1, +Infinity, -3]
# Minimum
# cusp 1/2 -9
# cusp 1/4 -3
# Newform number 1
# q - 82*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -9, +Infinity, +Infinity, +Infinity, -8, +Infinity, +Infinity, +Infinity, -9]
# cusp 1/4 [+Infinity, -3, +Infinity, +Infinity, +Infinity, -2, +Infinity, +Infinity, +Infinity, -3]
# Minimum
# cusp 1/2 -9
# cusp 1/4 -3
# Newform number 2
# q + 8*q^3 + 14*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -9, +Infinity, -6, +Infinity, -8, +Infinity, -5, +Infinity, -9]
# cusp 1/4 [+Infinity, -3, +Infinity, 0, +Infinity, -2, +Infinity, 1, +Infinity, -3]
# Minimum
# cusp 1/2 -9
# cusp 1/4 -3
# WEIGHT 8
# Number of ratioal newforms 1
# Newform number 0
# q - 58*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, +Infinity, +Infinity, -11, +Infinity, +Infinity, +Infinity, -12]
# cusp 1/4 [+Infinity, -4, +Infinity, +Infinity, +Infinity, -3, +Infinity, +Infinity, +Infinity, -4]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -4
# WEIGHT 10
# Number of ratioal newforms 1
# Newform number 0
# q + 2398*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -15, +Infinity, +Infinity, +Infinity, -14, +Infinity, +Infinity, +Infinity, -15]
# cusp 1/4 [+Infinity, -5, +Infinity, +Infinity, +Infinity, -4, +Infinity, +Infinity, +Infinity, -5]
# Minimum
# cusp 1/2 -15
# cusp 1/4 -5
# WEIGHT 12
# Number of ratioal newforms 1
# Newform number 0
# q - 12938*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -18, +Infinity, +Infinity, +Infinity, -17, +Infinity, +Infinity, +Infinity, -18]
# cusp 1/4 [+Infinity, -6, +Infinity, +Infinity, +Infinity, -5, +Infinity, +Infinity, +Infinity, -6]
# Minimum
# cusp 1/2 -18
# cusp 1/4 -6
# ALL MINIMA, cusp 1/2 {2: [-3], 4: [-6, -6, -6], 6: [-9, -9, -9], 8: [-12], 10: [-15], 12: [-18]}
# All MINIMA, cusp 1/4 {2: [-1], 4: [-2, -2, -2], 6: [-3, -3, -3], 8: [-4], 10: [-5], 12: [-6]}

# %%
p=2; N=p^6;
print 'LEVEL', N
minima = {}
minima2 = {}
minima3 = {}
for k in range(2,10,2):
    minima[k] = []
    minima2[k] = []
    minima3[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of ratioal newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s3 = get_expansion(n, mat = 1/p^3, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        K2 = s2.series.base_ring()
        K3 = s3.series.base_ring()
        P = K.prime_above(p)
        P2 = K2.prime_above(p)
        P3 = K3.prime_above(p)
        print('Denominators')
        print 'cusp 1/2', [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'cusp 1/4', [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
        print 'cusp 1/8', [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
        print 'Minimum'
        print 'cusp 1/2', min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        print 'cusp 1/4', min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)])
        print 'cusp 1/8', min([valuation(s3[i],P3)/P3.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        minima2[k].append(min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]))
        minima3[k].append(min([valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA, cusp 1/2', minima
print 'All MINIMA, cusp 1/4', minima2
print 'All MINIMA, cusp 1/8', minima3
# Out:
# LEVEL 64
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q + 2*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -4, +Infinity, +Infinity, +Infinity, -3, +Infinity, +Infinity, +Infinity, -4]
# cusp 1/4 [+Infinity, -2, +Infinity, +Infinity, +Infinity, -1, +Infinity, +Infinity, +Infinity, -2]
# cusp 1/8 [+Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -4
# cusp 1/4 -2
# cusp 1/8 1
# WEIGHT 4
# Number of ratioal newforms 5
# Newform number 0
# q - 8*q^3 + 10*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -5, +Infinity, -7, +Infinity, -4, +Infinity, -8]
# cusp 1/4 [+Infinity, -4, +Infinity, -1, +Infinity, -3, +Infinity, 0, +Infinity, -4]
# cusp 1/8 [+Infinity, +Infinity, 2, +Infinity, +Infinity, +Infinity, 5, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 -4
# cusp 1/8 2
# Newform number 1
# q - 4*q^3 + 2*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/4 [+Infinity, -4, +Infinity, -2, +Infinity, -3, +Infinity, -1, +Infinity, -4]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 7/2, +Infinity, +Infinity, +Infinity, 11/2, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 -4
# cusp 1/8 7/2
# Newform number 2
# q - 22*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, +Infinity, +Infinity, -7, +Infinity, +Infinity, +Infinity, -8]
# cusp 1/4 [+Infinity, -4, +Infinity, +Infinity, +Infinity, -3, +Infinity, +Infinity, +Infinity, -4]
# cusp 1/8 [+Infinity, +Infinity, 2, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 -4
# cusp 1/8 2
# Newform number 3
# q + 4*q^3 + 2*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/4 [+Infinity, -4, +Infinity, -2, +Infinity, -3, +Infinity, -1, +Infinity, -4]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 7/2, +Infinity, +Infinity, +Infinity, 11/2, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 -4
# cusp 1/8 7/2
# Newform number 4
# q + 8*q^3 + 10*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -8, +Infinity, -5, +Infinity, -7, +Infinity, -4, +Infinity, -8]
# cusp 1/4 [+Infinity, -4, +Infinity, -1, +Infinity, -3, +Infinity, 0, +Infinity, -4]
# cusp 1/8 [+Infinity, +Infinity, 2, +Infinity, +Infinity, +Infinity, 5, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -8
# cusp 1/4 -4
# cusp 1/8 2
# WEIGHT 6
# Number of ratioal newforms 7
# Newform number 0
# q - 20*q^3 + 74*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 11/2, +Infinity, +Infinity, +Infinity, 17/2, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 11/2
# Newform number 1
# q - 12*q^3 - 54*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 11/2, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 11/2
# Newform number 2
# q - 8*q^3 - 14*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -9, +Infinity, -11, +Infinity, -8, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -3, +Infinity, -5, +Infinity, -2, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, 3, +Infinity, +Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 3
# Newform number 3
# q + 82*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, +Infinity, +Infinity, -11, +Infinity, +Infinity, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, +Infinity, +Infinity, -5, +Infinity, +Infinity, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, 3, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 3
# Newform number 4
# q + 8*q^3 - 14*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -9, +Infinity, -11, +Infinity, -8, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -3, +Infinity, -5, +Infinity, -2, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, 3, +Infinity, +Infinity, +Infinity, 6, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 3
# Newform number 5
# q + 12*q^3 - 54*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 11/2, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 11/2
# Newform number 6
# q + 20*q^3 + 74*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -12, +Infinity, -10, +Infinity, -11, +Infinity, -9, +Infinity, -12]
# cusp 1/4 [+Infinity, -6, +Infinity, -4, +Infinity, -5, +Infinity, -3, +Infinity, -6]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 11/2, +Infinity, +Infinity, +Infinity, 17/2, +Infinity]
# Minimum
# cusp 1/2 -12
# cusp 1/4 -6
# cusp 1/8 11/2
# WEIGHT 8
# Number of ratioal newforms 7
# Newform number 0
# q - 84*q^3 + 82*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, 23/2, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# Newform number 1
# q - 44*q^3 - 430*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, 23/2, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# Newform number 2
# q - 12*q^3 + 210*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# Newform number 3
# q + 58*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, +Infinity, +Infinity, -15, +Infinity, +Infinity, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, +Infinity, +Infinity, -7, +Infinity, +Infinity, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, 4, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 4
# Newform number 4
# q + 12*q^3 + 210*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# Newform number 5
# q + 44*q^3 - 430*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, 23/2, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# Newform number 6
# q + 84*q^3 + 82*q^5 + O(q^6)
# Denominators
# cusp 1/2 [+Infinity, -16, +Infinity, -14, +Infinity, -15, +Infinity, -13, +Infinity, -16]
# cusp 1/4 [+Infinity, -8, +Infinity, -6, +Infinity, -7, +Infinity, -5, +Infinity, -8]
# cusp 1/8 [+Infinity, +Infinity, +Infinity, +Infinity, 15/2, +Infinity, +Infinity, +Infinity, 23/2, +Infinity]
# Minimum
# cusp 1/2 -16
# cusp 1/4 -8
# cusp 1/8 15/2
# ALL MINIMA, cusp 1/2 {8: [-16, -16, -16, -16, -16, -16, -16], 2: [-4], 4: [-8, -8, -8, -8, -8], 6: [-12, -12, -12, -12, -12, -12, -12]}
# All MINIMA, cusp 1/4 {8: [-8, -8, -8, -8, -8, -8, -8], 2: [-2], 4: [-4, -4, -4, -4, -4], 6: [-6, -6, -6, -6, -6, -6, -6]}
# All MINIMA, cusp 1/8 {8: [15/2, 15/2, 15/2, 4, 15/2, 15/2, 15/2], 2: [1], 4: [2, 7/2, 2, 7/2, 2], 6: [11/2, 11/2, 3, 3, 3, 11/2, 11/2]}

# %%
p=2; N=3*p^6;
print 'LEVEL', N
minima = {}
minima2 = {}
minima3 = {}
for k in range(2,4,2):
    minima[k] = []
    minima2[k] = []
    minima3[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of ratioal newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s3 = get_expansion(n, mat = 1/p^3, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        K2 = s2.series.base_ring()
        K3 = s3.series.base_ring()
        P = K.prime_above(p)
        P2 = K2.prime_above(p)
        P3 = K3.prime_above(p)
        print('Denominators')
        print 'cusp 1/2', [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'cusp 1/4', [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
        print 'cusp 1/8', [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
        print 'Minimum'
        print 'cusp 1/2', min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        print 'cusp 1/4', min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)])
        print 'cusp 1/8', min([valuation(s3[i],P3)/P3.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        minima2[k].append(min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]))
        minima3[k].append(min([valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA, cusp 1/2', minima
print 'All MINIMA, cusp 1/4', minima2
print 'All MINIMA, cusp 1/8', minima3
# Out:
# LEVEL 192
# WEIGHT 2
# Number of ratioal newforms 4
# Newform number 0
# q - q^3 - 2*q^5 + O(q^6)
# Could not write form as lin. comb. of Eisenstein series and products of Eisenstein series
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-9d7854821056> in <module>()
#      17         print 'Newform number', j
#      18         print n
# ---> 19         s = get_expansion(n, mat = Integer(1)/p, prec=Integer(10),verbose=False); #Calculate Fourier expansion of the newform
#      20         s2 = get_expansion(n, mat = Integer(1)/p**Integer(2), prec=Integer(10),verbose=False); #Calculate Fourier expansion of the newform
#      21         s3 = get_expansion(n, mat = Integer(1)/p**Integer(3), prec=Integer(10),verbose=False); #Calculate Fourier expansion of the newform
#
# /home/neururer/products-of-eisenstein-series/get_expansions.py in get_expansion(f, prec, mat, group, base_ring, verbose, eis_alt)
#     145     if verbose:
#     146         print('Finding coefficients of linear combination...')
# --> 147     sol, ind = lin_comb(f, verbose=verbose)
#     148     if verbose:
#     149         print('{} coefficients are non-zero'.
#
# TypeError: 'NoneType' object is not iterable

# %%
p=2; N=p^8;
print 'LEVEL', N
minima = {}
for k in range(2,6,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima

# %%
p=3; N=p^3;
print 'LEVEL', N
minima = {}
for k in range(2,10,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
# Out:
# LEVEL 27
# WEIGHT 2
# Number of ratioal newforms 1
# Newform number 0
# q - 2*q^4 + O(q^6)
# Denominators
# [+Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity]
# Minimum
# -1
# WEIGHT 4
# Number of ratioal newforms 2
# Newform number 0
# q - 3*q^2 + q^4 - 15*q^5 + O(q^6)
# Denominators
# [+Infinity, -2, -1, +Infinity, -2, -1, +Infinity, -2, -1, +Infinity]
# Minimum
# -2
# Newform number 1
# q + 3*q^2 + q^4 + 15*q^5 + O(q^6)
# Denominators
# [+Infinity, -2, -1, +Infinity, -2, -1, +Infinity, -2, -1, +Infinity]
# Minimum
# -2
# WEIGHT 6
# Number of ratioal newforms 1
# Newform number 0
# q - 32*q^4 + O(q^6)
# Denominators
# [+Infinity, -3, +Infinity, +Infinity, -3, +Infinity, +Infinity, -3, +Infinity, +Infinity]
# Minimum
# -3
# WEIGHT 8
# Number of ratioal newforms 1
# Newform number 0
# q - 128*q^4 + O(q^6)
# Denominators
# [+Infinity, -4, +Infinity, +Infinity, -4, +Infinity, +Infinity, -4, +Infinity, +Infinity]
# Minimum
# -4
# ALL MINIMA {8: [-4], 2: [-1], 4: [-2, -2], 6: [-3]}

# %%
p=3; N=p^4;
print 'LEVEL', N
minima = {}
minima2 = {}
for k in range(2,14,2):
    minima[k] = []
    minima2[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        s2 = get_expansion(n, mat = 1/p^2, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        K2 = s2.series.base_ring()
        P = K.prime_above(p)
        P2 = K2.prime_above(p)
        print('Denominators')
        print 'cusp 1/3', [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'cusp 1/9', [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
        print 'Minimum'
        print 'cusp 1/3', min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        print 'cusp 1/9', min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        minima2[k].append(min([valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA, cusp 1/3', minima
print 'All MINIMA, cusp 1/9', minima2
# Out:
# LEVEL 81
# WEIGHT 2
# Number of ratioal newforms 0
# WEIGHT 4
# Number of ratioal newforms 0
# WEIGHT 6
# Number of ratioal newforms 0
# WEIGHT 8
# Number of ratioal newforms 0
# WEIGHT 10
# Number of ratioal newforms 0
# WEIGHT 12
# Number of ratioal newforms 0
# ALL MINIMA, cusp 1/3 {2: [], 4: [], 6: [], 8: [], 10: [], 12: []}
# All MINIMA, cusp 1/9 {2: [], 4: [], 6: [], 8: [], 10: [], 12: []}

# %%
p=3; N=p^5;
print 'LEVEL', N
minima = {}
for k in range(2,4,2):
    minima[k] = []
    print 'WEIGHT', k
    New = Newforms(N,k,names='a');
    print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
    j=0
    for n in New: #Loop over all newforms of given level N and weight k
        if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
            continue
        print 'Newform number', j
        print n
        s = get_expansion(n, mat = 1/p, prec=10,verbose=False); #Calculate Fourier expansion of the newform
        K = s.series.base_ring() #Number field
        P = K.prime_above(p)
        print('Denominators')
        print [valuation(s[i],P)/P.ramification_index() for i in range(10)]
        print 'Minimum'
        print min([valuation(s[i],P)/P.ramification_index() for i in range(10)])
        minima[k].append(min([valuation(s[i],P)/P.ramification_index() for i in range(10)]))
        j+=1
print 'ALL MINIMA', minima
