# %% [markdown]
# # This sage worksheet accompanies my paper  (joint with Abhishek Saha and Kęstutis Česnavičius)
# # <p style="text-align: center;"> ['The Manin constant and the modular degree'](https://arxiv.org/abs/1911.09446) </p>

# %% [markdown]
# # Denominators of Fourier expansions
# We calculate, for various levels $N$ and weights $k$, the denominators of Fourier expansions of all newforms at some cusps of $X_0(N)$. Examples from this worksheet were used to generate the tables 4.8.1 and 4.8.2 from the paper.
#
# ### <font color ="green"> Requirements: SageMath and the function get_expansions from the python package [products-of-eisenstein-series](https://github.com/michaelneururer/products-of-eisenstein-series) (joint work with Martin Dickson) to calculate the Fourier expansions. </font>

# %%
p=2; N=5*p^2;
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print latex(n.qexp(10))
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 20
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q - 2q^{3} - q^{5} + 2q^{7} + q^{9} + O(q^{10})
# Cusp 1/2 1/5*zeta40^4*q5 - 2/5*zeta40^12*q5^3 + 1/5*q5^5 - 2/5*zeta40^8*q5^7 + (-1/5*zeta40^12 + 1/5*zeta40^8 - 1/5*zeta40^4 + 1/5)*q5^9 + 2/5*zeta40^12*q5^13 - 2/5*q5^15 + 6/5*zeta40^8*q5^17 + (4/5*zeta40^12 - 4/5*zeta40^8 + 4/5*zeta40^4 - 4/5)*q5^19 - 4/5*zeta40^4*q5^21 + 6/5*zeta40^12*q5^23 - 1/5*q5^25 - 4/5*zeta40^8*q5^27 + (-6/5*
^17 + 4/5*zeta40^12*q5^19 - 4/5*zeta40^8*q5^21 - 6/5*zeta40^4*q5^23 + 1/5*q5^25 + (4/5*zeta40^12 - 4/5*zeta40^8 + 4/5*zeta40^4 - 4/5)*q5^27 - 6/5*zeta40^12*q5^29 - 4/5*zeta40^8*q5^31 - 2/5*q5^35 + (2/5*zeta40^12 - 2/5*zeta40^8 + 2/5*zeta40^4 - 2/5)*q5^37 + 4/5*zeta40^12*q5^39 + 6/5*zeta40^8*q5^41 + 2*zeta40^4*q5^43 - 1/5*q5^45 + (-6/5*zeta40^12 + 6/5*zeta40^8 - 6/5*zeta40^4 + 6/5)*q5^47 + 3/5*zeta40^12*q5^49 + O(q5^50)
#
# Denominators Cusp 1/2
# [+Infinity, 0, +Infinity, 1, +Infinity, 0, +Infinity, 1, +Infinity, 0]
# Denominators Cusp 1/4
# [+Infinity, 0, +Infinity, 1, +Infinity, 0, +Infinity, 1, +Infinity, 0]
# Denominators Cusp 1/8
# [+Infinity, 0, +Infinity, 1, +Infinity, 0, +Infinity, 1, +Infinity, 0]
# Denominators Cusp 1/16
# [+Infinity, 0, +Infinity, 1, +Infinity, 0, +Infinity, 1, +Infinity, 0]

# %%
p=2; N=3*p^3;
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print latex(n.qexp(10))
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 24
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q - q^{3} - 2q^{5} + q^{9} + O(q^{10})
# Denominators Cusp 1/16
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]

# %%
p=2; N=3*p^4;
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print latex(n.qexp(10))
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 48
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q + q^{3} - 2q^{5} + q^{9} + O(q^{10})
# Cusp 1/2 1/12*zeta48^2*q12 + 1/12*zeta48^6*q12^3 - 1/6*zeta48^10*q12^5 + (1/12*zeta48^10 - 1/12*zeta48^2)*q12^9 + (-1/3*zeta48^14 + 1/3*zeta48^6)*q12^11 + 1/6*zeta48^2*q12^13 + 1/6*zeta48^6*q12^15 - 1/6*zeta48^10*q12^17 - 1/3*zeta48^14*q12^19 + (-2/3*zeta48^14 + 2/3*zeta48^6)*q12^23 - 1/12*zeta48^2*q12^25 + 1/12*zeta48^6*q12^27 + 1/2*zeta48^10*q12^29 - 2/3*zeta48^14*q12^31 + (-1/3*zeta48^10 + 1/3*zeta48^2)*q12^33 - 1/2*zeta48^2*q12^37 + 1/6*zeta48^6*q12^39 + 1/2*zeta48^10*q12^41 + 1/3*zeta48^14*q12^43 + (1/6*zeta48^10 - 1/6*zeta48^2)*q12^45 - 7/12*zeta48^2*q12^49 + 1/6*zeta48^6*q12^51 - 1/6*zeta48^10*q12^53 + 2/3*zeta48^14*q12^55 + (1/3*zeta48^10 - 1/3*zeta48^2)*q12^57 + (-1/3*zeta48^14 + 1/3*zeta48^6)*q12^59 + 1/6*zeta48^2*q12^61 - 1/3*zeta48^10*q12^65 - 1/3*zeta48^14*q12^67 + (-2/3*zeta48^10 + 2/3*zeta48^2)*q12^69 + (2/3*zeta48^14 - 2/3*zeta48^6)*q12^71 + 5/6*zeta48^2*q12^73 - 1/12*zeta48^6*q12^75 + 2/3*zeta48^14*q12^79 + (1/12*zeta48^10 - 1/12*zeta48^2)*q12^81 + (1/3*zeta48^14 - 1/3*zeta48^6)*q12^83 + 1/3*zeta48^2*q12^85 - 1/2*zeta48^6*q12^87 + 1/2*zeta48^10*q12^89 + (2/3*zeta48^10 - 2/3*zeta48^2)*q12^93 + (2/3*zeta48^14 - 2/3*zeta48^6)*q12^95 + 1/6*zeta48^2*q12^97 - 1/3*zeta48^6*q12^99 - 3/2*zeta48^10*q12^101 - 4/3*zeta48^14*q12^103 + (zeta48^14 - zeta48^6)*q12^107 + 1/6*zeta48^2*q12^109 - 1/2*zeta48^6*q12^111 - 3/2*zeta48^10*q12^113 + 4/3*zeta48^14*q12^115 + (1/6*zeta48^10 - 1/6*zeta48^2)*q12^117 + O(q12^120)
#
# Cusp 1/4 (-2/3*zeta48^12 + 2/3*zeta48^4)*q3^2 - 2/3*zeta48^12*q3^6 + 4/3*zeta48^4*q3^10 + 2/3*zeta48^12*q3^18 - 8/3*zeta48^4*q3^22 + (4/3*zeta48^12 - 4/3*zeta48^4)*q3^26 + O(q3^30)
#
# Cusp 1/8 -1/3*zeta48^8*q3 + 1/3*q3^3 + (-2/3*zeta48^8 + 2/3)*q3^5 + 1/3*q3^9 + (-4/3*zeta48^8 + 4/3)*q3^11 + 2/3*zeta48^8*q3^13 - 2/3*q3^15 + (2/3*zeta48^8 - 2/3)*q3^17 - 4/3*zeta48^8*q3^19 + (8/3*zeta48^8 - 8/3)*q3^23 + 1/3*zeta48^8*q3^25 + 1/3*q3^27 + (2*zeta48^8 - 2)*q3^29 + O(q3^30)
#
# Cusp 1/16 (-1/3*zeta48^8 + 1/3)*q3 - 1/3*q3^3 - 2/3*zeta48^8*q3^5 - 1/3*q3^9 - 4/3*zeta48^8*q3^11 + (2/3*zeta48^8 - 2/3)*q3^13 + 2/3*q3^15 + 2/3*zeta48^8*q3^17 + (-4/3*zeta48^8 + 4/3)*q3^19 + 8/3*zeta48^8*q3^23 + (1/3*zeta48^8 - 1/3)*q3^25 - 1/3*q3^27 + 2*zeta48^8*q3^29 + O(q3^30)
#
# Denominators Cusp 1/2
# [+Infinity, -2, +Infinity, -2, +Infinity, -1, +Infinity, +Infinity, +Infinity, -2]
# Denominators Cusp 1/4
# [+Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity]
# Denominators Cusp 1/8
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]
# Denominators Cusp 1/16
# [+Infinity, 0, +Infinity, 0, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]

# %%
p=2; N=p^5;
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n.qexp(10)
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 32
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q - 2*q^5 - 3*q^9 + O(q^10)
# Cusp 1/2 1/8*zeta32^2*q8 - 1/4*zeta32^10*q8^5 + 3/8*zeta32^2*q8^9 - 3/4*zeta32^10*q8^13 + 1/4*zeta32^2*q8^17 + 1/8*zeta32^2*q8^25 + 5/4*zeta32^10*q8^29 - 1/4*zeta32^10*q8^37 - 5/4*zeta32^2*q8^41 - 3/4*zeta32^10*q8^45 - 7/8*zeta32^2*q8^49 + 7/4*zeta32^10*q8^53 + 5/4*zeta32^10*q8^61 - 3/2*zeta32^2*q8^65 + 3/4*zeta32^2*q8^73 + O(q8^80)
#
# Cusp 1/4 -1/2*zeta32^12*q2 - zeta32^12*q2^5 + 3/2*zeta32^12*q2^9 + 3*zeta32^12*q2^13 - zeta32^12*q2^17 + O(q2^20)
#
# Cusp 1/8 -zeta32^8*q1 + 2*zeta32^8*q1^5 + 3*zeta32^8*q1^9 + O(q1^10)
#
# Cusp 1/16 -q1 + 2*q1^5 + 3*q1^9 + O(q1^10)
#
# Denominators Cusp 1/2
# [+Infinity, -3, +Infinity, +Infinity, +Infinity, -2, +Infinity, +Infinity, +Infinity, -3]
# Denominators Cusp 1/4
# [+Infinity, -1, +Infinity, +Infinity, +Infinity, 0, +Infinity, +Infinity, +Infinity, -1]
# Denominators Cusp 1/8
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]
# Denominators Cusp 1/16
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]

# %%
p=2; N=p^6
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n.qexp(10)
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 64
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q + 2*q^5 - 3*q^9 + O(q^10)
# Cusp 1/2 1/16*zeta64^2*q16 + 1/8*zeta64^10*q16^5 - 3/16*zeta64^18*q16^9 - 3/8*zeta64^26*q16^13 - 1/8*zeta64^2*q16^17 + 1/16*zeta64^18*q16^25 - 5/8*zeta64^26*q16^29 + 1/8*zeta64^10*q16^37 + 5/8*zeta64^18*q16^41 - 3/8*zeta64^26*q16^45 + 7/16*zeta64^2*q16^49 + 7/8*zeta64^10*q16^53 - 5/8*zeta64^26*q16^61 - 3/4*zeta64^2*q16^65 - 3/8*zeta64^18*q16^73 - 9/16*zeta64^2*q16^81 - 1/4*zeta64^10*q16^85 - 5/8*zeta64^18*q16^89 + 9/8*zeta64^2*q16^97 + 1/8*zeta64^10*q16^101 - 3/8*zeta64^26*q16^109 + 7/8*zeta64^2*q16^113 - 9/8*zeta64^10*q16^117 + 11/16*zeta64^18*q16^121 + 3/4*zeta64^26*q16^125 - 11/8*zeta64^18*q16^137 - 5/4*zeta64^2*q16^145 + 7/8*zeta64^10*q16^149 + 3/8*zeta64^18*q16^153 + 11/8*zeta64^26*q16^157 + O(q16^160)
#
# Cusp 1/4 -1/4*zeta64^20*q4 + 1/2*zeta64^4*q4^5 - 3/4*zeta64^20*q4^9 + 3/2*zeta64^4*q4^13 - 1/2*zeta64^20*q4^17 - 1/4*zeta64^20*q4^25 - 5/2*zeta64^4*q4^29 + 1/2*zeta64^4*q4^37 + O(q4^40)
#
# Cusp 1/8 -2*zeta64^24*q1^2 + O(q1^10)
#
# Cusp 1/16 -zeta64^16*q1 - 2*zeta64^16*q1^5 + 3*zeta64^16*q1^9 + O(q1^10)
#
# Denominators Cusp 1/2
# [+Infinity, -4, +Infinity, +Infinity, +Infinity, -3, +Infinity, +Infinity, +Infinity, -4]
# Denominators Cusp 1/4
# [+Infinity, -2, +Infinity, +Infinity, +Infinity, -1, +Infinity, +Infinity, +Infinity, -2]
# Denominators Cusp 1/8
# [+Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]
# Denominators Cusp 1/16
# [+Infinity, 0, +Infinity, +Infinity, +Infinity, 1, +Infinity, +Infinity, +Infinity, 0]

# %%
p=2; N=p^7
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 128
# Number newforms 4
# Number of rational newforms 4
# Newform number 0
# q - 2*q^3 - 2*q^5 + O(q^6)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 256
# Number newforms 5
# Number of rational newforms 4
# Newform number 0
# q - 2*q^3 + O(q^6)
# L-function vanishes at 1, so we provide no expansions here
# Newform number 0
# q - 4*q^5 + O(q^6)
# L-function vanishes at 1, so we provide no expansions here
# Newform number 0
# q + 4*q^5 + O(q^6)
# Cusp 1/2 1/64*zeta256^2*q64 + 1/16*zeta256^10*q64^5 - 3/64*zeta256^18*q64^9 + 1/16*zeta256^26*q64^13 - 1/32*zeta256^34*q64^17 + 11/64*zeta256^50*q64^25 + 1/16*zeta256^58*q64^29 - 3/16*zeta256^74*q64^37 - 5/32*zeta256^82*q64^41 - 3/16*zeta256^90*q64^45 - 7/64*zeta256^98*q64^49 + 1/16*zeta256^106*q64^53 - 3/16*zeta256^122*q64^61 - 1/4*zeta256^2*q64^65 + 3/32*zeta256^18*q64^73 - 9/64*zeta256^34*q64^81 + 1/8*zeta256^42*q64^85 - 5/32*zeta256^50*q64^89 + 9/32*zeta256^66*q64^97 - 5/16*zeta256^74*q64^101 - 5/16*zeta256^90*q64^109 + 7/32*zeta256^98*q64^113 + 3/16*zeta256^106*q64^117 + 11/64*zeta256^114*q64^121 - 3/8*zeta256^122*q64^125 + 11/32*zeta256^18*q64^137 + 1/4*zeta256^34*q64^145 + 5/16*zeta256^42*q64^149 + 3/32*zeta256^50*q64^153 - 3/16*zeta256^58*q64^157 + 3/64*zeta256^82*q64
# Cusp 1/4 1/16*zeta256^68*q16 - 1/8*zeta256^76*q16^3 + 1/16*zeta256^100*q16^9 - 3/8*zeta256^108*q16^11 + 3/8*zeta256^4*q16^17 + 1/8*zeta256^12*q16^19 + 5/16*zeta256^36*q16^25 - 1/4*zeta256^44*q16^27 - 3/4*zeta256^68*q16^33 - 3/8*zeta256^100*q16^41 - 5/8*zeta256^108*q16^43 - 7/16*zeta256^4*q16^49 + 3/4*zeta256^12*q16^51 + 1/4*zeta256^36*q16^57 - 3/8*zeta256^44*q16^59 + 7/8*zeta256^76*q16^67 - 1/8*zeta256^100*q16^73 + 5/8*zeta256^108*q16^75 + 11/16*zeta256^4*q16^81 + 9/8*zeta256^12*q16^83 + 9/8*zeta256^36*q16^89 - 5/8*zeta256^68*q16^97 + 3/8*zeta256^76*q16^99 + 3/8*zeta256^108*q16^107 + 9/8*zeta256^4*q16^113 + 25/16*zeta256^36*q16^121 - 3/4*zeta256^44*q16^123 - 5/4*zeta256^68*q16^129 - 9/8*zeta256^76*q16^131 + 3/8*zeta256^100*q16^137 - 11/8*zeta256^108*q16^139 - 7/8*zeta256^12*q16^147 + 3/8*zeta256^36*q16^153 + O(q16^160)
#
# Cusp 1/8 -1/4*zeta256^104*q4 - 1/2*zeta256^56*q4^3 + 1/4*zeta256^40*q4^9 - 3/2*zeta256^120*q4^11 - 3/2*zeta256^104*q4^17 + 1/2*zeta256^56*q4^19 + 5/4*zeta256^40*q4^25 - zeta256^120*q4^27 - 3*zeta256^104*q4^33 + O(q4^40)
#
# Cusp 1/16 (-2*zeta256^112 - 2*zeta256^80 - 2*zeta256^48 + 2*zeta256^16)*q1^4 + O(q1^10)
#
# Denominators Cusp 1/2
# [+Infinity, -6, +Infinity, -5, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, -6]
# Denominators Cusp 1/4
# [+Infinity, -4, +Infinity, -3, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, -4]
# Denominators Cusp 1/8
# [+Infinity, -2, +Infinity, -1, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity, -2]
# Denominators Cusp 1/16
# [+Infinity, +Infinity, +Infinity, +Infinity, 7/4, +Infinity, +Infinity, +Infinity, +Infinity, +Infinity]

# %%
p=3; N=5*p^2
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s3 = get_expansion(n, mat = Matrix(2,2,[1,-2,3,-5]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s9 = get_expansion(n, mat = Matrix(2,2,[2,1,9,5]), prec=10,verbose=False);
    print 'Cusp 1/3', latex(s3)
    print 'Cusp 1/9', latex(s9)
    K3 = s3.series.base_ring() #Number field
    P3 = K3.prime_above(p)
    print('Denominators Cusp 1/3')
    print [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
    K9 = s9.series.base_ring() #Number field
    P9 = K9.prime_above(p)
    print('Denominators Cusp 1/9')
    print [valuation(s9[i],P9)/P9.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 45
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q + q^2 - q^4 - q^5 + O(q^6)
# Cusp 1/3 (-1/15*zeta360^60 - 1/15)*q5 + (1/15*zeta360^60 - 2/15)*q5^2 + (-8/15*zeta360^60 + 4/15)*q5^3 + (1/15*zeta360^60 + 1/15)*q5^4 + (-1/15*zeta360^60 + 2/15)*q5^5 + (8/15*zeta360^60 - 4/15)*q5^6 + (-1/5*zeta360^60 + 2/5)*q5^8 + (8/15*zeta360^60 - 4/15)*q5^9 + (1/15*zeta360^60 + 1/15)*q5^10 + (4/15*zeta360^60 - 8/15)*q5^11 + (8/15*zeta360^60 - 4/15)*q5^12 + (2/15*zeta360^60 + 2/15)*q5^13 + (-8/15*zeta360^60 + 4/15)*q5^15 + (1/15*zeta360^60 + 1/15)*q5^16 + (-2/15*zeta360^60 + 4/15)*q5^17 + (-8/15*zeta360^60 + 4/15)*q5^18 + (-4/15*zeta360^60 - 4/15)*q5^19 + (1/15*zeta360^60 - 2/15)*q5^20 + (-4/15*zeta360^60 - 4/15)*q5^22 + (-8/5*zeta360^60 + 4/5)*q5^24 + (-1/15*zeta360^60 - 1/15)*q5^25 + (-2/15*zeta360^60 + 4/15)*q5^26 + (-8/15*zeta360^60 + 4/15)*q5^27 + (2/15*zeta360^60 - 4/15)*q5^29 + (8/15*zeta360^60 - 4/15)*q5^30 + (1/3*zeta360^60 - 2/3)*q5^32 + (32/15*zeta360^60 - 16/15)*q5^33 + (2/15*zeta360^60 + 2/15)*q5^34 + (-8/15*zeta360^60 + 4/15)*q5^36 + (2/3*zeta360^60 + 2/3)*q5^37 + (4/15*zeta360^60 - 8/15)*q5^38 + (16/15*zeta360^60 - 8/15)*q5^39 + (-1/5*zeta360^60 - 1/5)*q5^40 + (-2/3*zeta360^60 + 4/3)*q5^41 + (-4/15*zeta360^60 - 4/15)*q5^43 + (-4/15*zeta360^60 + 8/15)*q5^44 + (8/15*zeta360^60 - 4/15)*q5^45 + (-8/15*zeta360^60 + 16/15)*q5^47 + (8/15*zeta360^60 - 4/15)*q5^48 + (7/15*zeta360^60 + 7/15)*q5^49 + O(q5^50)
#
# Cusp 1/9 1/5*q5 + 1/5*q5^2 - 1/5*q5^4 - 1/5*q5^5 - 3/5*q5^8 - 1/5*q5^10 + 4/5*q5^11 - 2/5*q5^13 - 1/5*q5^16 - 2/5*q5^17 + 4/5*q5^19 + 1/5*q5^20 + 4/5*q5^22 + 1/5*q5^25 - 2/5*q5^26 + 2/5*q5^29 + q5^32 - 2/5*q5^34 - 2*q5^37 + 4/5*q5^38 + 3/5*q5^40 - 2*q5^41 + 4/5*q5^43 - 4/5*q5^44 - 8/5*q5^47 - 7/5*q5^49 + O(q5^50)
#
# Denominators Cusp 1/3
# [+Infinity, -1/2, -1/2, -1/2, -1/2, -1/2, -1/2, +Infinity, 1/2, -1/2]
# Denominators Cusp 1/9
# [+Infinity, 0, 0, +Infinity, 0, 0, +Infinity, +Infinity, 1, +Infinity]

# %%
s9_2 = get_expansion(n, mat = Matrix(2,2,[1,0,9,1]), prec=10,verbose=False);

# %%
[valuation(s9_2[i],P9)/P9.ramification_index() for i in range(10)]
# Out:
# [+Infinity, 0, 0, +Infinity, 0, 0, +Infinity, +Infinity, 1, +Infinity]

# %%
p=3; N=p^3
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s3 = get_expansion(n, mat = Matrix(2,2,[1,-2,3,-5]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s9 = get_expansion(n, mat = Matrix(2,2,[2,1,9,5]), prec=10,verbose=False);
    print 'Cusp 1/3', latex(s3)
    print 'Cusp 1/9', latex(s9)
    K3 = s3.series.base_ring() #Number field
    P3 = K3.prime_above(p)
    print('Denominators Cusp 1/3')
    print [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
    K9 = s9.series.base_ring() #Number field
    P9 = K9.prime_above(p)
    print('Denominators Cusp 1/9')
    print [valuation(s9[i],P9)/P9.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 27
# Number newforms 1
# Number of rational newforms 1
# Newform number 0
# q - 2*q^4 + O(q^6)
# Cusp 1/3 1/3*zeta54^15*q3 + 2/3*zeta54^6*q3^4 + (1/3*zeta54^15 - 1/3*zeta54^6)*q3^7 - 5/3*zeta54^6*q3^13 + (-4/3*zeta54^15 + 4/3*zeta54^6)*q3^16 - 7/3*zeta54^15*q3^19 + (5/3*zeta54^15 - 5/3*zeta54^6)*q3^25 + 2/3*zeta54^15*q3^28 + O(q3^30)
#
# Cusp 1/9 (zeta54^9 - 1)*q1 + (-2*zeta54^9 + 2)*q1^4 + (-zeta54^9 + 1)*q1^7 + O(q1^10)
#
# Denominators Cusp 1/3
# [+Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity]
# Denominators Cusp 1/9
# [+Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity, 0, +Infinity, +Infinity]

# %%
p=3; N=2*p^4
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s3 = get_expansion(n, mat = Matrix(2,2,[1,-2,3,-5]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s9 = get_expansion(n, mat = Matrix(2,2,[2,1,9,5]), prec=10,verbose=False);
    print 'Cusp 1/3', latex(s3)
    print 'Cusp 1/9', latex(s9)
    K3 = s3.series.base_ring() #Number field
    P3 = K3.prime_above(p)
    print('Denominators Cusp 1/3')
    print [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
    K9 = s9.series.base_ring() #Number field
    P9 = K9.prime_above(p)
    print('Denominators Cusp 1/9')
    print [valuation(s9[i],P9)/P9.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 162
# Number newforms 4
# Number of rational newforms 4
# Newform number 0
# q - q^2 + q^4 - 3*q^5 + O(q^6)
# L-function vanishes at 1, so we provide no expansions here
# Newform number 0
# q - q^2 + q^4 + O(q^6)
# Cusp 1/3 -1/18*zeta162^39*q18 + (1/18*zeta162^51 - 1/18*zeta162^24)*q18^2 + (1/18*zeta162^48 - 1/18*zeta162^21)*q18^4 + 1/9*zeta162^30*q18^7 + (-1/18*zeta162^42 + 1/18*zeta162^15)*q18^8 + 1/6*zeta162^24*q18^11 - 1/9*zeta162^21*q18^13 + (1/9*zeta162^33 - 1/9*zeta162^6)*q18^14 + (1/18*zeta162^30 - 1/18*zeta162^3)*q18^16 - 1/6*zeta162^15*q18^17 - 1/18*zeta162^12*q18^19 + 1/6*zeta162^48*q18^22 + 1/3*zeta162^6*q18^23 + 5/18*zeta162^3*q18^25 + 1/9*zeta162^42*q18^26 + 1/9*zeta162^39*q18^28 + (-1/3*zeta162^51 + 1/3*zeta162^24)*q18^29 + (2/9*zeta162^48 - 2/9*zeta162^21)*q18^31 - 1/18*zeta162^33*q18^32 + 1/6*zeta162^30*q18^34 + (-2/9*zeta162^39 + 2/9*zeta162^12)*q18^37 - 1/18*zeta162^24*q18^38 + (-1/2*zeta162^33 + 1/2*zeta162^6)*q18^41 + (1/18*zeta162^30 - 1/18*zeta162^3)*q18^43 + 1/6*zeta162^15*q18^44 + 1/3*zeta162^12*q18^46 - 1/3*zeta162^51*q18^47 - 1/6*zeta162^48*q18^49 - 5/18*zeta162^6*q18^50 + 1/9*zeta162^3*q18^52 - 2/3*zeta162^42*q18^53 + (1/9*zeta162^51 - 1/9*zeta162^24)*q18^56 + (1/3*zeta162^48 - 1/3*zeta162^21)*q18^58 + 1/6*zeta162^33*q18^59 + 4/9*zeta162^30*q18^61 + (2/9*zeta162^42 - 2/9*zeta162^15)*q18^62 + (-1/18*zeta162^39 + 1/18*zeta162^12)*q18^64 - 5/18*zeta162^21*q18^67 + (-1/6*zeta162^33 + 1/6*zeta162^6)*q18^68 - 2/3*zeta162^15*q18^71 + 11/18*zeta162^12*q18^73 + 2/9*zeta162^51*q18^74 + 1/18*zeta162^48*q18^76 + 1/3*zeta162^6*q18^77 + 2/9*zeta162^3*q18^79 + 1/2*zeta162^39*q18^82 + (-2/3*zeta162^51 + 2/3*zeta162^24)*q18^83 + 1/18*zeta162^33*q18^86 + 1/6*zeta162^30*q18^88 + (1/3*zeta162^42 - 1/3*zeta162^15)*q18^89 + (2/9*zeta162^39 - 2/9*zeta162^12)*q18^91 - 1/3*zeta162^24*q18^92 - 1/3*zeta162^21*q18^94 + (-5/18*zeta162^30 + 5/18*zeta162^3)*q18^97 + 1/6*zeta162^15*q18^98 + 5/18*zeta162^12*q18^100 + 7/9*zeta162^48*q18^103 + 1/9*zeta162^6*q18^104 + 2/3*zeta162^3*q18^106 - 1/6*zeta162^42*q18^107 + 8/9*zeta162^39*q18^109 + (1/9*zeta162^48 - 1/9*zeta162^21)*q18^112 + 1/3*zeta162^33*q18^113 + (-1/3*zeta162^42 + 1/3*zeta162^15)*q18^116 + (-1/6*zeta162^39 + 1/6*zeta162^12)*q18^118 + 1/3*zeta162^24*q18^119 + 1/9*zeta162^21*q18^121 + (4/9*zeta162^33 - 4/9*zeta162^6)*q18^122 + (-2/9*zeta162^30 + 2/9*zeta162^3)*q18^124 + 1/9*zeta162^12*q18^127 - 1/18*zeta162^51*q18^128 + 1/9*zeta162^3*q18^133 + 5/18*zeta162^42*q18^134 - 1/6*zeta162^39*q18^136 + (1/6*zeta162^51 - 1/6*zeta162^24)*q18^137 + (19/18*zeta162^48 - 19/18*zeta162^21)*q18^139 + 2/3*zeta162^30*q18^142 + (-1/3*zeta162^42 + 1/3*zeta162^15)*q18^143 + 11/18*zeta162^24*q18^146 - 2/9*zeta162^21*q18^148 + (1/3*zeta162^33 - 1/3*zeta162^6)*q18^149 + (5/9*zeta162^30 - 5/9*zeta162^3)*q18^151 + 1/18*zeta162^15*q18^152 + 1/3*zeta162^12*q18^154 - 2/9*zeta162^48*q18^157 - 2/9*zeta162^6*q18^158 + 2/3*zeta162^42*q18^161 + 2/9*zeta162^39*q18^163 + (1/2*zeta162^51 - 1/2*zeta162^24)*q18^164 + (2/3*zeta162^48 - 2/3*zeta162^21)*q18^166 - 2/3*zeta162^33*q18^167 - 1/2*zeta162^30*q18^169 + (1/18*zeta162^39 - 1/18*zeta162^12)*q18^172 + 1/3*zeta162^24*q18^173 + 5/9*zeta162^21*q18^175 + (-1/6*zeta162^33 + 1/6*zeta162^6)*q18^176 + (1/3*zeta162^30 - 1/3*zeta162^3)*q18^178 + 2/3*zeta162^15*q18^179 + O(q18^180)
#
# Cusp 1/9 (1/2*zeta162^45 + zeta162^36 - zeta162^18 - 1/2*zeta162^9)*q2^3 + (zeta162^45 - zeta162^36 - 1/2*zeta162^18 + 1/2*zeta162^9)*q2^6 + (3/2*zeta162^45 + 3/2*zeta162^36)*q2^9 + (zeta162^45 + 1/2*zeta162^36 - 1/2*zeta162^18 - zeta162^9)*q2^12 + (3/2*zeta162^45 - 3/2*zeta162^18 + 3/2*zeta162^9)*q2^18 + O(q2^20)
#
# Denominators Cusp 1/3
# [+Infinity, -2, -2, +Infinity, -2, +Infinity, +Infinity, -2, -2, +Infinity]
# Denominators Cusp 1/9
# [+Infinity, +Infinity, +Infinity, 1/2, +Infinity, +Infinity, 1/2, +Infinity, +Infinity, 7/6]
39 + 1/6*zeta162^12)*q18^118 - 1/3*zeta162^24*q18^119 + 1/9*zeta162^21*q18^121 + (-4/9*zeta162^33 + 4/9*zeta162^6)*q18^122 + (-2/9*zeta162^30 + 2/9*zeta162^3)*q18^124 + 1/9*zeta162^12*q18^127 + 1/18*zeta162^51*q18^128 + 1/9*zeta162^3*q18^133 - 5/18*zeta162^42*q18^134 - 1/6*zeta162^39*q18^136 + (-1/6*zeta162^51 + 1/6*zeta162^24)*q18^137 + (19/18*zeta162^48 - 19/18*zeta162^21)*q18^139 + 2/3*zeta162^30*q18^142 + (1/3*zeta162^42 - 1/3*zeta162^15)*q18^143 - 11/18*zeta162^24*q18^146 - 2/9*zeta162^21*q18^148 + (-1/3*zeta162^33 + 1/3*zeta162^6)*q18^149 + (5/9*zeta162^30 - 5/9*zeta162^3)*q18^151 - 1/18*zeta162^15*q18^152 + 1/3*zeta162^12*q18^154 - 2/9*zeta162^48*q18^157 + 2/9*zeta162^6*q18^158 - 2/3*zeta162^42*q18^161 + 2/9*zeta162^39*q18^163 + (-1/2*zeta162^51 + 1/2*zeta162^24)*q18^164 + (2/3*zeta162^48 - 2/3*zeta162^21)*q18^166 + 2/3*zeta162^33*q18^167 - 1/2*zeta162^30*q18^169 + (1/18*zeta162^39 - 1/18*zeta162^12)*q18^172 - 1/3*zeta162^24*q18^173 + 5/9*zeta162^21*q18^175 + (1/6*zeta162^33 - 1/6*zeta162^6)*q18^176 + (1/3*zeta162^30 - 1/3*zeta162^3)*q18^178 - 2/3*zeta162^15*q18^179 + O(q18^180)
#
# Cusp 1/9 (1/2*zeta162^45 - zeta162^36 - zeta162^18 + 1/2*zeta162^9)*q2^3 + (zeta162^45 + zeta162^36 - 1/2*zeta162^18 - 1/2*zeta162^9)*q2^6 + (3/2*zeta162^45 - 3/2*zeta162^36)*q2^9 + (zeta162^45 - 1/2*zeta162^36 - 1/2*zeta162^18 + zeta162^9)*q2^12 + (3/2*zeta162^45 - 3/2*zeta162^18 - 3/2*zeta162^9)*q2^18 + O(q2^20)
#
# Denominators Cusp 1/3
# [+Infinity, -2, -2, +Infinity, -2, +Infinity, +Infinity, -2, -2, +Infinity]
# Denominators Cusp 1/9
# [+Infinity, +Infinity, +Infinity, 2/3, +Infinity, +Infinity, 2/3, +Infinity, +Infinity, 1]
# Newform number 2
# q + q^2 + q^4 + 3*q^5 + O(q^6)
# Cusp 1/3 1/18*zeta162^12*q18 - 1/18*zeta162^24*q18^2 - 1/18*zeta162^48*q18^4 + (1/6*zeta162^33 - 1/6*zeta162^6)*q18^5 + 2/9*zeta162^3*q18^7 + 1/18*zeta162^15*q18^8 + 1/6*zeta162^39*q18^10 + (1/18*zeta162^48 - 1/18*zeta162^21)*q18^13 + 2/9*zeta162^6*q18^14 - 1/18*zeta162^30*q18^16 + 1/6*zeta162^42*q18^17 + (-2/9*zeta162^39 + 2/9*zeta162^12)*q18^19 + (-1/6*zeta162^51 + 1/6*zeta162^24)*q18^20 + (-2/9*zeta
q18^137 + 10/9*zeta162^48*q18^139 + (2/3*zeta162^33 - 2/3*zeta162^6)*q18^140 + 2/3*zeta162^3*q18^142 + 3/2*zeta162^39*q18^145 + 11/18*zeta162^51*q18^146 + (-1/18*zeta162^48 + 1/18*zeta162^21)*q18^148 - 1/2*zeta162^6*q18^149 + 4/9*zeta162^30*q18^151 + 2/9*zeta162^42*q18^152 + (-2/3*zeta162^51 + 2/3*zeta162^24)*q18^155 + 13/18*zeta162^21*q18^157 - 8/9*zeta162^33*q18^158 + (1/6*zeta162^30 - 1/6*zeta162^3)*q18^160 + 4/9*zeta162^12*q18^163 + 1/3*zeta162^24*q18^164 - 2/3*zeta162^48*q18^166 + (-2/3*zeta162^33 + 2/3*zeta162^6)*q18^167 + 2/3*zeta162^3*q18^169 + 1/2*zeta162^15*q18^170 + 4/9*zeta162^39*q18^172 - 1/6*zeta162^51*q18^173 + (8/9*zeta162^48 - 8/9*zeta162^21)*q18^175 - 1/6*zeta162^30*q18^178 - 2/3*zeta162^42*q18^179 + O(q18^180)
#
# Cusp 1/9 (-1/2*zeta162^36 + 1/2*zeta162^9)*q2 + 1/2*zeta162^45*q2^2 + 1/2*zeta162^9*q2^4 + (3/2*zeta162^45 - 3/2*zeta162^18)*q2^5 - 2*zeta162^36*q2^7 - 1/2*zeta162^18*q2^8 + (3/2*zeta162^36 - 3/2*zeta162^9)*q2^10 + 1/2*zeta162^9*q2^13 + (2*zeta162^45 - 2*zeta162^18)*q2^14 - 1/2*zeta162^36*q2^16 + 3/2*zeta162^18*q2^17 + (2*zeta162^36 - 2*zeta162^9)*q2^19 + O(q2^20)
#
# Denominators Cusp 1/3
# [+Infinity, -2, -2, +Infinity, -2, -1, +Infinity, -2, -2, +Infinity]
# Denominators Cusp 1/9
# [+Infinity, 0, 0, +Infinity, 0, 1, +Infinity, 0, 0, +Infinity]

# %%
p=3; N=p^5
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n
    if n.atkin_lehner_eigenvalue()==1:
        print 'L-function vanishes at 1, so we provide no expansions here'
        continue
    s3 = get_expansion(n, mat = Matrix(2,2,[1,-2,3,-5]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s9 = get_expansion(n, mat = Matrix(2,2,[2,1,9,5]), prec=10,verbose=False);
    print 'Cusp 1/3', latex(s3)
    print 'Cusp 1/9', latex(s9)
    K3 = s3.series.base_ring() #Number field
    P3 = K3.prime_above(p)
    print('Denominators Cusp 1/3')
    print [valuation(s3[i],P3)/P3.ramification_index() for i in range(10)]
    K9 = s9.series.base_ring() #Number field
    P9 = K9.prime_above(p)
    print('Denominators Cusp 1/9')
    print [valuation(s9[i],P9)/P9.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 243
# Denominators Cusp 1/9
# [+Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity, -1, +Infinity, +Infinity]

# %% [markdown]
# # Here we study the case v_2(N)=6

# %%
p=2; N=3*p^6
print 'LEVEL', N
New = Newforms(N,2,names='a');
print 'Number newforms', len(New)
print 'Number of rational newforms', len([n for n in New if n.base_ring()==QQ])
j=0
for n in New: #Loop over all newforms of given level N and weight k
    if not n.base_ring() == QQ: #Skip newforms which don't have rational Fourier coefficients
        continue
    print 'Newform number', j
    print n.qexp(10)
    s2 = get_expansion(n, mat = Matrix(2,2,[1,0,2,1]), prec=10,verbose=False); #Calculate Fourier expansion of the newform
    s4 = get_expansion(n, mat = Matrix(2,2,[1,0,4,1]), prec=10,verbose=False);
    s8 = get_expansion(n, mat = Matrix(2,2,[1,0,8,1]), prec=10,verbose=False);
    s16 = get_expansion(n, mat = Matrix(2,2,[1,0,16,1]), prec=10,verbose=False);
    print 'Cusp 1/2', latex(s2)
    print 'Cusp 1/4', latex(s4)
    print 'Cusp 1/8', latex(s8)
    print 'Cusp 1/16', latex(s16)
    K2 = s2.series.base_ring() #Number field
    P2 = K2.prime_above(p)
    print('Denominators Cusp 1/2')
    print [valuation(s2[i],P2)/P2.ramification_index() for i in range(10)]
    K4 = s4.series.base_ring() #Number field
    P4 = K4.prime_above(p)
    print('Denominators Cusp 1/4')
    print [valuation(s4[i],P4)/P4.ramification_index() for i in range(10)]
    K8 = s8.series.base_ring() #Number field
    P8 = K8.prime_above(p)
    print('Denominators Cusp 1/8')
    print [valuation(s8[i],P8)/P8.ramification_index() for i in range(10)]
    K16 = s16.series.base_ring() #Number field
    P16 = K16.prime_above(p)
    print('Denominators Cusp 1/16')
    print [valuation(s16[i],P16)/P16.ramification_index() for i in range(10)]
    j+=1
# Out:
# LEVEL 192
# Number newforms 4
# Number of rational newforms 4
# Newform number 0
# q - q^3 - 2*q^5 - 4*q^7 + q^9 + O(q^10)
# Could not write form as lin. comb. of Eisenstein series and products of Eisenstein series
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c64ddb328b87> in <module>()
#      10     print 'Newform number', j
#      11     print n.qexp(Integer(10))
# ---> 12     s2 = get_expansion(n, mat = Matrix(Integer(2),Integer(2),[Integer(1),Integer(0),Integer(2),Integer(1)]), prec=Integer(10),verbose=False); #Calculate Fourier expansion of the newform
#      13     s4 = get_expansion(n, mat = Matrix(Integer(2),Integer(2),[Integer(1),Integer(0),Integer(4),Integer(1)]), prec=Integer(10),verbose=False);
#      14     s8 = get_expansion(n, mat = Matrix(Integer(2),Integer(2),[Integer(1),Integer(0),Integer(8),Integer(1)]), prec=Integer(10),verbose=False);
#
# /home/neururer/products-of-eisenstein-series/get_expansions.py in get_expansion(f, prec, mat, group, base_ring, verbose, eis_alt)
#     145     if verbose:
#     146         print('Finding coefficients of linear combination...')
# --> 147     sol, ind = lin_comb(f, verbose=verbose)
#     148     if verbose:
#     149         print('{} coefficients are non-zero'.
#
# TypeError: 'NoneType' object is not iterable
